# %%
# %sql
use catalog hive_metastore

# %%
# %sql
DESCRIBE HISTORY employee

# %%
# %sql
SELECT*FROM EMPLOYEE VERSION AS OF 4

# %%
# %sql
SELECT * FROM employee@v4

# %%
# %sql
DELETE FROM EMPLOYEE

# %%
# %sql
SELECT *FROM employee

# %%
# %sql
RESTORE TABLE EMPLOYEE TO VERSION AS OF 6

# %%
# %sql
SELECT* FROM EMPLOYEE

# %%
# %sql
DESCRIBE HISTORY employee

# %%
# %sql
OPTIMIZE EMPLOYEE
ZORDER BY ID

# %%
# %sql
DESCRIBE DETAIL EMPLOYEE

# %%
# %sql
DESCRIBE HISTORY employee

# %%
# %fs ls 'dbfs:/user/hive/warehouse/employee'

# %%
# %sql
VACUUM employee

# %%
# %fs ls 'dbfs:/user/hive/warehouse/employee'

# %%
# %sql
VACUUM employee RETAIN 0 HOURS

# %%
# %fs ls 'dbfs:/user/hive/warehouse/employee'

# %%
# %sql
SELECT * FROM employee@v1

# %%
# %sql
DROP TABLE employee

# %%
# %sql
SELECT * FROM employee

# %%
# %fs ls 'dbfs:/user/hive/warehouse/employee'
